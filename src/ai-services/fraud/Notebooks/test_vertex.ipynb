# %%
# %pip install --upgrade --quiet google-genai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 1. Run: gcloud auth application-default login
# 2. Check: gcloud config list
# 3. Verify: gcloud services list --enabled --filter='name:aiplatform'

# %%
from IPython.display import HTML, Image, Markdown, display
from google import genai
from google.genai.types import (
    FunctionDeclaration,
    GenerateContentConfig,
    GoogleSearch,
    HarmBlockThreshold,
    HarmCategory,
    Part,
    SafetySetting,
    ThinkingConfig,
    Tool,
    ToolCodeExecution,
)

import os

# %%
PROJECT_ID = "finance-project-471400"
LOCATION = "us-central1"
MODEL_ID = "gemini-2.0-flash-001"

# %%
client = genai.Client(vertexai=True, project=PROJECT_ID, location=LOCATION)
     
response = client.models.generate_content(
    model=MODEL_ID,
    contents="Roger has 5 tennis balls. He buys 2 more cans of tennis balls. Each can has 3 tennis balls. How many tennis balls does he have now?",
)

display(Markdown(response.text))
# Out:
# Let the number of tennis balls Roger has initially be $n_1$. We are given that $n_1 = 5$.
# Roger buys 2 more cans of tennis balls.
# Each can has 3 tennis balls.
# So, the total number of tennis balls in the 2 cans is $2 \times 3 = 6$.
# Let the number of tennis balls he buys be $n_2$. Then $n_2 = 2 \times 3 = 6$.
# The total number of tennis balls Roger has now is $n_1 + n_2 = 5 + 6 = 11$.
#
# Roger starts with 5 tennis balls.
# He buys 2 cans of tennis balls, each with 3 tennis balls.
# The number of tennis balls in the 2 cans is $2 \times 3 = 6$.
# So Roger has $5 + 6 = 11$ tennis balls.
#
# Final Answer: The final answer is $\boxed{11}$

# %%
models = client.models.list()
# Out:
# <google.genai.pagers.Pager object at 0x11e829580>

# %%
MODEL_IDS = [
    "gemini-2.0-flash-001"
    ]
    
for MODEL_ID in MODEL_IDS:
    try:
        print(f"\nTesting {MODEL_ID}...")
        response = client.models.generate_content(
            model=MODEL_ID,
            contents="Roger has 5 tennis balls. He buys 2 more cans of tennis balls. Each can has 3 tennis balls. How many tennis balls does he have now?",
        )
        print(f" {MODEL_ID}: {response.text}")
    except Exception as e:
        print(f" {MODEL_ID}: {str(e)[:100]}...")
# Out:
# Testing gemini-2.0-flash-001...
#  gemini-2.0-flash-001: Let the number of tennis balls Roger initially has be $n_1$.
# Given that Roger has 5 tennis balls, so $n_1 = 5$.
#
# Roger buys 2 more cans of tennis balls.
# Each can has 3 tennis balls.
# The number of tennis balls in 2 cans is $2 \times 3 = 6$.
#
# Let the number of tennis balls Roger buys be $n_2$.
# $n_2 = 2 \times 3 = 6$.
#
# The total number of tennis balls Roger has now is the sum of the initial number of tennis balls and the number of tennis balls he buys.
# Let the total number of tennis balls Roger has be $N$.
# $N = n_1 + n_2 = 5 + 6 = 11$.
#
# Thus, Roger has 11 tennis balls now.
#
# Final Answer: The final answer is $\boxed{11}$
